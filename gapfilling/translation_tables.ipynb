# %%
import cobra
import csv
from json2xml import json2xml
from json2xml.utils import readfromjson
import csv
import os
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# We will use MetaNetX xref tables for converting ModelSEED compounds/reactions into BiGG nomenclature. The tables have been downloaded from:
# https://www.metanetx.org/mnxdoc/mnxref.html

# %%
# translator for compounds; removing header and those which don't belong to BiGG or ModelSEED
os.system('cat metanetx/chem_xref.tsv | grep "bigg\|seedM" | tail -n +4 > metanetx/grep_chemm.tsv ')
# Out:
# 0

# %%
# loading the file
compounds_df = pd.read_csv("metanetx/grep_chemm.tsv", sep = "\t", header = None)

# %%
compounds_df
# Out:
#                       0          1  \
# 0      seedM:M_cpd11416    BIOMASS
# 1        seedM:cpd11416    BIOMASS
# 2      seedM:M_cpd28297      MNXM0
# 3        seedM:cpd28297      MNXM0
# 4           biggM:M_oh1     MNXM02
# ...                 ...        ...
# 86202    seedM:cpd33563  MNXM99992
# 86203       biggM:M_h2o      WATER
# 86204         biggM:h2o      WATER
# 86205  seedM:M_cpd00001      WATER
# 86206    seedM:cpd00001      WATER
#
#                                                        2
# 0                  secondary/obsolete/fantasy identifier
# 1                                                Biomass
# 2                  secondary/obsolete/fantasy identifier
# 3                                                UNKNOWN
# 4                  secondary/obsolete/fantasy identifier
# ...                                                  ...
# 86202          (9Z,11E)-tetradeca-9,11-dien-1-yl acetate
# 86203              secondary/obsolete/fantasy identifier
# 86204                                                H2O
# 86205              secondary/obsolete/fantasy identifier
# 86206  H2O||H20||H3O+||HO-||Hydroxide ion||OH||OH-||W...
#
# [86207 rows x 3 columns]

# %%
# removing obsolete IDs
notobsolete = compounds_df[2] != 'secondary/obsolete/fantasy identifier'
filtered_compounds_df = compounds_df[notobsolete]
filtered_compounds_df.head()
# Out:
#                 0        1                   2
# 1  seedM:cpd11416  BIOMASS             Biomass
# 3  seedM:cpd28297    MNXM0             UNKNOWN
# 5       biggM:oh1   MNXM02       Hydroxide ion
# 7  seedM:cpd15275   MNXM02  hydroxide ion||oh1
# 9         biggM:h    MNXM1                  H+

# %%
# removing third column which we don't need
del filtered_compounds_df[2]

# %%
filtered_compounds_df.head()
# Out:
#                 0        1
# 1  seedM:cpd11416  BIOMASS
# 3  seedM:cpd28297    MNXM0
# 5       biggM:oh1   MNXM02
# 7  seedM:cpd15275   MNXM02
# 9         biggM:h    MNXM1

# %%
# separating the words in the first column
w = list(filtered_compounds_df[0])
# number of metabolites (bigg + seed)
len(w)
# Out:
# 43082

# %%
l = []
for i in range(len(w)):
    l.append(w[i].split(":"))
compounds = DataFrame(l)
compounds.head()
# Out:
#        0         1
# 0  seedM  cpd11416
# 1  seedM  cpd28297
# 2  biggM       oh1
# 3  seedM  cpd15275
# 4  biggM         h

# %%
# MetaNetX IDs
m = list(filtered_compounds_df[1])
compounds[2] = m
compounds.head()
# Out:
#        0         1        2
# 0  seedM  cpd11416  BIOMASS
# 1  seedM  cpd28297    MNXM0
# 2  biggM       oh1   MNXM02
# 3  seedM  cpd15275   MNXM02
# 4  biggM         h    MNXM1

# %% [markdown]
# Now that we have a purged table we can use it for translating metabolites.

# %%
seed = compounds[compounds[0] == "seedM"]
seed
# Out:
#            0         1          2
# 0      seedM  cpd11416    BIOMASS
# 1      seedM  cpd28297      MNXM0
# 3      seedM  cpd15275     MNXM02
# 5      seedM  cpd00067      MNXM1
# 7      seedM  cpd00004     MNXM10
# ...      ...       ...        ...
# 43076  seedM  cpd28907  MNXM99969
# 43077  seedM  cpd23431   MNXM9997
# 43078  seedM  cpd25878   MNXM9999
# 43079  seedM  cpd33563  MNXM99992
# 43081  seedM  cpd00001      WATER
#
# [33995 rows x 3 columns]

# %%
bigg = compounds[compounds[0] == "biggM"]
bigg
# Out:
#            0         1         2
# 2      biggM       oh1    MNXM02
# 4      biggM         h     MNXM1
# 6      biggM      nadh    MNXM10
# 8      biggM      grdp   MNXM100
# 17     biggM  prostgf2  MNXM1001
# ...      ...       ...       ...
# 42981  biggM  3htmelys   MNXM990
# 43001  biggM    4mptnl   MNXM992
# 43011  biggM  3AStrmyn  MNXM9930
# 43013  biggM   35cdamp  MNXM9931
# 43080  biggM       h2o     WATER
#
# [9087 rows x 3 columns]

# %%
del bigg[0]
del seed[0]

# %%
bigg = bigg.reset_index(drop = True)

# %%
seed = seed.reset_index(drop = True)

# %%
# keys -> bigg; values -> seed
C = {}

# %%
for i in range(len(bigg)):
    m_id = bigg[2][i]
    b_id = bigg[1][i]
    try:
        s_id = seed[seed[2] == m_id][1].values[0]
    except IndexError:
        continue
    C[b_id] = s_id

# %%
C_df = DataFrame(data = {'BiGG': C.keys(), 'SEED': C.values()})

# %%
C_df
# Out:
#           BiGG      SEED
# 0          oh1  cpd15275
# 1            h  cpd00067
# 2         nadh  cpd00004
# 3         grdp  cpd00283
# 4     prostgf2  cpd00488
# ...        ...       ...
# 2630  3htmelys  cpd00923
# 2631    4mptnl  cpd01585
# 2632  3AStrmyn  cpd02250
# 2633   35cdamp  cpd00713
# 2634       h2o  cpd00001
#
# [2635 rows x 2 columns]

# %%
# Saving table
C_df.to_csv(r'compounds.tsv', header = True, index = False, sep = "\t")

# %%
# translator for reactions
os.system('cat metanetx/reac_xref.tsv | grep "bigg\|seedM" | tail -n +4 > metanetx/grep_reac.tsv ')
# Out:
# 0

# %%
reactions_df = pd.read_csv("metanetx/grep_reac.tsv", sep = "\t", header = None)

# %%
reactions_df[:20]
# Out:
#                    0       1  \
# 0       biggR:CRBNTD   EMPTY
# 1      biggR:H2CO3D2   EMPTY
# 2     biggR:H2CO3D2m   EMPTY
# 3     biggR:HMR_5409   EMPTY
# 4      biggR:RE2594C   EMPTY
# 5     biggR:R_CRBNTD   EMPTY
# 6    biggR:R_H2CO3D2   EMPTY
# 7   biggR:R_H2CO3D2m   EMPTY
# 8   biggR:R_HMR_5409   EMPTY
# 9    biggR:R_RE2594C   EMPTY
# 10    seedR:rxn22163   EMPTY
# 11    seedR:rxn40958   EMPTY
# 12    seedR:rxn42499   EMPTY
# 13    seedR:rxn48508   EMPTY
# 14      biggR:EX_h_e  MNXR02
# 15    biggR:R_EX_h_e  MNXR02
# 16    biggR:HMR_1095  MNXR03
# 17          biggR:Ht  MNXR03
# 18        biggR:Htcx  MNXR03
# 19        biggR:Htex  MNXR03
#
#                                                     2
# 0   H2CO3 dissociation||1 biggM:h2co3@biggC:x = 1 ...
# 1   Carboxylic acid dissociation||1 biggM:h2co3@bi...
# 2   Carboxylic acid dissociation, mitochondrial||1...
# 3   HMR 5409||1 biggM:h@biggC:e + 1 biggM:hco3@big...
# 4   RE2594||1 biggM:h@biggC:c + 1 biggM:CE2949@big...
# 5               secondary/obsolete/fantasy identifier
# 6               secondary/obsolete/fantasy identifier
# 7               secondary/obsolete/fantasy identifier
# 8               secondary/obsolete/fantasy identifier
# 9               secondary/obsolete/fantasy identifier
# 10  RXN0-5219.c||1 seedM:cpd00013@seedC:0 <=> 1 se...
# 11  rxn40958||1 seedM:cpd05262@seedC:0 <=> 1 seedM...
# 12  rxn42499||1 seedM:cpd00067@seedC:0 + 1 seedM:c...
# 13  rxn48508||1 seedM:cpd19028@seedC:0 <=> 1 seedM...
# 14  H+ exchange||1 biggM:h@BOUNDARY = 1 biggM:h@bi...
# 15              secondary/obsolete/fantasy identifier
# 16    HMR 1095||1 biggM:h@biggC:n = 1 biggM:h@biggC:c
# 17  Proton diffusion||1 biggM:h@biggC:c = 1 biggM:...
# 18  Proton transport to carboxysome via diffusion|...
# 19  Proton transport via diffusion (extracellular ...

# %%
# Let's remove obsolete IDs
notobsolete = reactions_df[2] != 'secondary/obsolete/fantasy identifier'
notob_reactions_df = reactions_df[notobsolete]

# %%
notob_reactions_df[:10]
# Out:
#                  0       1                                                  2
# 0     biggR:CRBNTD   EMPTY  H2CO3 dissociation||1 biggM:h2co3@biggC:x = 1 ...
# 1    biggR:H2CO3D2   EMPTY  Carboxylic acid dissociation||1 biggM:h2co3@bi...
# 2   biggR:H2CO3D2m   EMPTY  Carboxylic acid dissociation, mitochondrial||1...
# 3   biggR:HMR_5409   EMPTY  HMR 5409||1 biggM:h@biggC:e + 1 biggM:hco3@big...
# 4    biggR:RE2594C   EMPTY  RE2594||1 biggM:h@biggC:c + 1 biggM:CE2949@big...
# 10  seedR:rxn22163   EMPTY  RXN0-5219.c||1 seedM:cpd00013@seedC:0 <=> 1 se...
# 11  seedR:rxn40958   EMPTY  rxn40958||1 seedM:cpd05262@seedC:0 <=> 1 seedM...
# 12  seedR:rxn42499   EMPTY  rxn42499||1 seedM:cpd00067@seedC:0 + 1 seedM:c...
# 13  seedR:rxn48508   EMPTY  rxn48508||1 seedM:cpd19028@seedC:0 <=> 1 seedM...
# 14    biggR:EX_h_e  MNXR02  H+ exchange||1 biggM:h@BOUNDARY = 1 biggM:h@bi...

# %%
# Now we will remove rows with "EMPTY" in the second column
notempty = reactions_df[1] != 'EMPTY'
filtered_reactions_df = notob_reactions_df[notempty]
filtered_reactions_df[:10]
# Out:
# <ipython-input-86-8bd0d533b0ea>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_reactions_df = notob_reactions_df[notempty]
#                  0       1                                                  2
# 14    biggR:EX_h_e  MNXR02  H+ exchange||1 biggM:h@BOUNDARY = 1 biggM:h@bi...
# 16  biggR:HMR_1095  MNXR03    HMR 1095||1 biggM:h@biggC:n = 1 biggM:h@biggC:c
# 17        biggR:Ht  MNXR03  Proton diffusion||1 biggM:h@biggC:c = 1 biggM:...
# 18      biggR:Htcx  MNXR03  Proton transport to carboxysome via diffusion|...
# 19      biggR:Htex  MNXR03  Proton transport via diffusion (extracellular ...
# 20       biggR:Htg  MNXR03  Proton transport, Golgi||1 biggM:h@biggC:c = 1...
# 21       biggR:Hth  MNXR03  H transporter,by diffusiontoapicoplast||1 bigg...
# 22       biggR:Htl  MNXR03         Htl||1 biggM:h@biggC:c = 1 biggM:h@biggC:l
# 23       biggR:Htm  MNXR03  Uncoupling protein||1 biggM:h@biggC:m = 1 bigg...
# 24   biggR:Htm_cho  MNXR03  Uncoupling protein||1 biggM:h@biggC:m = 1 bigg...

# %%
# same as compounds
del filtered_reactions_df[2]

# %%
w = list(filtered_reactions_df[0])
len(w)
# Out:
# 72016

# %%
l = []
for i in range(len(w)):
    l.append(w[i].split(":"))
reactions = DataFrame(l)
reactions.head()
# Out:
#        0         1
# 0  biggR    EX_h_e
# 1  biggR  HMR_1095
# 2  biggR        Ht
# 3  biggR      Htcx
# 4  biggR      Htex

# %%
m = list(filtered_reactions_df[1])
reactions[2] = m
reactions.head()
# Out:
#        0         1       2
# 0  biggR    EX_h_e  MNXR02
# 1  biggR  HMR_1095  MNXR03
# 2  biggR        Ht  MNXR03
# 3  biggR      Htcx  MNXR03
# 4  biggR      Htex  MNXR03

# %%
bigg = reactions[reactions[0] == "biggR"]
bigg
# Out:
#            0              1          2
# 0      biggR         EX_h_e     MNXR02
# 1      biggR       HMR_1095     MNXR03
# 2      biggR             Ht     MNXR03
# 3      biggR           Htcx     MNXR03
# 4      biggR           Htex     MNXR03
# ...      ...            ...        ...
# 72011  biggR      GALNACT1g  MNXR99995
# 72012  biggR  GALNACT1g_cho  MNXR99996
# 72013  biggR      GALNACT2g  MNXR99997
# 72014  biggR      GALNACT3g  MNXR99998
# 72015  biggR      GALNACT4g  MNXR99999
#
# [28165 rows x 3 columns]

# %%
seed = reactions[reactions[0] == "seedR"]
seed
# Out:
#            0         1          2
# 16     seedR  rxn08730     MNXR03
# 17     seedR  rxn11009     MNXR03
# 18     seedR  rxn13646     MNXR03
# 19     seedR  rxn22797     MNXR03
# 20     seedR  rxn26298     MNXR03
# ...      ...       ...        ...
# 71949  seedR  rxn02173  MNXR99957
# 71951  seedR  rxn08576  MNXR99958
# 71954  seedR  rxn08577  MNXR99959
# 71957  seedR  rxn08579  MNXR99961
# 71960  seedR  rxn10687  MNXR99965
#
# [43851 rows x 3 columns]

# %%
del bigg[0]
del seed[0]

# %%
bigg = bigg.reset_index(drop = True)
seed = seed.reset_index(drop = True)

# %%
R = {}

# %%
for i in range(len(bigg)):
    m_id = bigg[2][i]
    b_id = bigg[1][i]
    try:
        s_id = seed[seed[2] == m_id][1].values[0]
    except IndexError:
        continue
    R[b_id] = s_id

# %%
R
# Out:
# {'HMR_1095': 'rxn08730',
#  'Ht': 'rxn08730',
#  'Htcx': 'rxn08730',
#  'Htex': 'rxn08730',
#  'Htg': 'rxn08730',
#  'Hth': 'rxn08730',
#  'Htl': 'rxn08730',
#  'Htm': 'rxn08730',
#  'Htm_cho': 'rxn08730',
#  'Htmi': 'rxn08730',
#  'Htr': 'rxn08730',
#  'Hts': 'rxn08730',
#  'Htu': 'rxn08730',
#  'Htx': 'rxn08730',
#  'PCXHtpp': 'rxn08730',
#  'GALTpts': 'rxn05567',
#  'GALTptspp': 'rxn05567',
#  'EX_galt_e': 'rxn08587',
#  'GALTt': 'rxn08587',
#  'GALTtex': 'rxn08587',
#  'GALh': 'rxn00187',
#  'GALm': 'rxn00187',
#  'GLNS': 'rxn00187',
#  'GAM': 'rxn00189',
#  'GLUN': 'rxn00189',
#  'GLUNm': 'rxn00189',
#  'GLUNpp': 'rxn00189',
#  'EX_gam6p_e': 'rxn05568',
#  'GAM6Pt': 'rxn05568',
#  'GAMAN6Ptex': 'rxn05568',
#  'GAM6Pt6_2pp': 'rxn08590',
#  'GAMpts': 'rxn05569',
#  'GAMptspp': 'rxn05569',
#  'EX_gam_e': 'rxn08593',
#  'GAMt1r': 'rxn08593',
#  'GAMtex': 'rxn08593',
#  'GART': 'rxn04783',
#  'EX_ga_e': 'rxn12797',
#  'GAt1': 'rxn12797',
#  'GAt2pp': 'rxn12798',
#  'GCALDD': 'rxn00979',
#  'GCALDDm': 'rxn00979',
#  'EX_gcald_e': 'rxn09680',
#  'GCALDt': 'rxn09680',
#  'GCALDtm': 'rxn09680',
#  'SK_gcald_c': 'rxn09680',
#  'GCAROtu': 'rxn33009',
#  'GCATENEC': 'rxn11574',
#  'LCYB': 'rxn11574',
#  'LYCBC2_h': 'rxn11574',
#  'GCC2': 'rxn09498',
#  'GCC2bim': 'rxn09498',
#  'GCC2am': 'rxn09499',
#  'GCC2cm': 'rxn01241',
#  'PDHcr': 'rxn01241',
#  'PDHe3hr': 'rxn01241',
#  'GCL': 'rxn00646',
#  'GLUCYS': 'rxn00646',
#  'GCLDH': 'rxn35210',
#  'GDBTALDH': 'rxn02273',
#  'GDH_nadp': 'rxn00184',
#  'GLUDy': 'rxn00184',
#  'GLUDym': 'rxn00184',
#  'GDPDPK': 'rxn08598',
#  'GDPTPDP': 'rxn26396',
#  'GDPt3g': 'rxn09705',
#  'EX_gdp_e': 'rxn08600',
#  'GDPtex': 'rxn08600',
#  'GDPtg': 'rxn08600',
#  'GDPtn': 'rxn08600',
#  'GDR': 'rxn00070',
#  'GDRh': 'rxn00070',
#  'GDRm': 'rxn00070',
#  'GDR_nadp_h': 'rxn00086',
#  'GTHOm': 'rxn00086',
#  'GTHOr': 'rxn00086',
#  'GDTP': 'rxn02449',
#  'GTPDPDP': 'rxn02449',
#  'GF4GL_3': 'rxn10528',
#  'GF4GL_4': 'rxn10529',
#  'GF4GL_5': 'rxn10530',
#  'GF4GL_6': 'rxn10531',
#  'GGDPtu': 'rxn32719',
#  'GGGABADr': 'rxn05127',
#  'GGGABAH': 'rxn05128',
#  'GGGPS': 'rxn17641',
#  'GGPP': 'rxn04038',
#  'GGPS': 'rxn03635',
#  'GGTAe2': 'rxn00350',
#  'GTHRDH_syn': 'rxn00350',
#  'GTHRDHpp': 'rxn00350',
#  'GHMT2r': 'rxn00692',
#  'GHMT2rc': 'rxn00692',
#  'GHMT2rm': 'rxn00692',
#  'GHMT3': 'rxn02351',
#  'GHMT3m': 'rxn02351',
#  'HTMLA_m': 'rxn02351',
#  'GK1': 'rxn00239',
#  'GK1er': 'rxn00239',
#  'GK1m': 'rxn00239',
#  'GK2': 'rxn09562',
#  'GLCDe': 'rxn08608',
#  'GLCDpp': 'rxn08608',
#  'GLCGLYCabcpp_syn': 'rxn05194',
#  'GLCNACT': 'rxn35300',
#  'GLCNt2ir': 'rxn05571',
#  'GLCNt2r': 'rxn05571',
#  'GLCNt2rpp': 'rxn05571',
#  'EX_glcn__D_e': 'rxn08610',
#  'EX_glcn_e': 'rxn08610',
#  'GLCNte': 'rxn08610',
#  'GLCNtex': 'rxn08610',
#  'GLCOAS': 'rxn01730',
#  'GLCRAL': 'rxn01990',
#  'GLCRAL_1': 'rxn01990',
#  'GLCURt2r': 'rxn05574',
#  'GLCURt2rpp': 'rxn05574',
#  'GLCURtly': 'rxn05574',
#  'EX_glcur_e': 'rxn08623',
#  'GLCURter': 'rxn08623',
#  'GLCURtex': 'rxn08623',
#  'GLCURtr': 'rxn08623',
#  'GLCabc': 'rxn05147',
#  'GLCabcpp': 'rxn05147',
#  'GLCpts': 'rxn05226',
#  'GLCptspp': 'rxn05226',
#  'GLCt2': 'rxn05573',
#  'GLCt2pp': 'rxn05573',
#  'GLMS_syn': 'rxn12822',
#  'GLTS_h': 'rxn12822',
#  'GLUS_ferr': 'rxn12822',
#  'GLUSfx': 'rxn12822',
#  'GLNLASEer': 'rxn02100',
#  'GLNSP1': 'rxn03406',
#  'GLNabc': 'rxn05155',
#  'GLNabcpp': 'rxn05155',
#  'EX_gln__L_e': 'rxn08625',
#  'GLNt': 'rxn08625',
#  'GLNtex': 'rxn08625',
#  'GLNtm': 'rxn08625',
#  'SK_gln__L_c': 'rxn08625',
#  'GLNt2n': 'rxn09678',
#  'GLNt2r': 'rxn09678',
#  'GLNt7': 'rxn09678',
#  'GLNth': 'rxn09678',
#  'GLNtm_1': 'rxn09678',
#  'GLNt4': 'rxn05216',
#  'GLNt6': 'rxn13301',
#  'GLRASE': 'rxn02278',
#  'GLU4ABUTthi': 'rxn08628',
#  'GLU4ABUTtmi': 'rxn08628',
#  'GLUABUTt7': 'rxn08628',
#  'GLUABUTt7pp': 'rxn08628',
#  'GLU5K': 'rxn00179',
#  'GLU5Km': 'rxn00179',
#  'GLUK': 'rxn09502',
#  'GLUNA1th': 'rxn05298',
#  'GLUNA1tm': 'rxn05298',
#  'GLUt4': 'rxn05298',
#  'GLUt4pp': 'rxn05298',
#  'GLUPRT': 'rxn00790',
#  'PRDPARh': 'rxn00790',
#  'GLUR': 'rxn00193',
#  'GLTS_m': 'rxn00069',
#  'GLUS': 'rxn00069',
#  'GLUSx': 'rxn00069',
#  'GLUS_nadph': 'rxn00085',
#  'GLUSy': 'rxn00085',
#  'GLU_Dt2': 'rxn05672',
#  'GLUabc': 'rxn05146',
#  'GLUabcpp': 'rxn05146',
#  'GLUt2m': 'rxn05297',
#  'GLUt2n': 'rxn05297',
#  'GLUt2r': 'rxn05297',
#  'GLUt2rpp': 'rxn05297',
#  'GLUt7': 'rxn05297',
#  'GLUth': 'rxn05297',
#  'GLXCBL': 'rxn00010',
#  'GLXCL': 'rxn00010',
#  'GLXO1': 'rxn05734',
#  'GLXO2p': 'rxn00325',
#  'GLXO3r': 'rxn00325',
#  'EX_glx_e': 'rxn09839',
#  'GLXt': 'rxn09839',
#  'GLXt_h': 'rxn09839',
#  'GLXtm': 'rxn09839',
#  'GLXtp': 'rxn09839',
#  'GLXt2': 'rxn05577',
#  'EX_glyc3p_e': 'rxn08643',
#  'GLY3Pt': 'rxn08643',
#  'GLYC3Ptex': 'rxn08643',
#  'GLYC3Pth': 'rxn08643',
#  'GLYC3Ptm': 'rxn08643',
#  'GLYC3tr': 'rxn08643',
#  'GLY3Pt2': 'rxn05578',
#  'GLYALDDr': 'rxn01286',
#  'r0393': 'rxn01286',
#  'EX_glyald_e': 'rxn08635',
#  'GLYALDt': 'rxn08635',
#  'GLYALDtex': 'rxn08635',
#  'GLYALDtpp': 'rxn08635',
#  'GLYAMDTR': 'rxn00404',
#  'GLYAMDTRc': 'rxn00404',
#  'GLYAT': 'rxn00273',
#  'GLYATm': 'rxn00273',
#  'GLYATx': 'rxn00273',
#  'GLYBabc': 'rxn05181',
#  'GLYBabcpp': 'rxn05181',
#  'GLYBt2pp': 'rxn05579',
#  'GLYBt2r': 'rxn05579',
#  'EX_glyb_e': 'rxn08639',
#  'GLYBtex': 'rxn08639',
#  'GLYBtm': 'rxn08639',
#  'GLYC2Pabcpp': 'rxn29217',
#  'EX_glyc2p_e': 'rxn08640',
#  'GLYC2Ptex': 'rxn08640',
#  'GLYC3Pabc': 'rxn05158',
#  'GLYC3Pabcpp': 'rxn05158',
#  'GLYC3Pt6': 'rxn08642',
#  'GLYC3Pt6pp': 'rxn08642',
#  'r2472': 'rxn08642',
#  'GLYCDH': 'rxn00768',
#  'GLYCDH_1': 'rxn01011',
#  'HPYRRx': 'rxn01011',
#  'HPYRRx_1': 'rxn01011',
#  'GLYCDx': 'rxn00762',
#  'GLYCDy': 'rxn00764',
#  'GLYCK': 'rxn01102',
#  'GLYCK_1': 'rxn01102',
#  'GLYPT': 'rxn01102',
#  'r0340': 'rxn01102',
#  'GLYCK2': 'rxn08647',
#  'GLYCL': 'rxn00908',
#  'GLYCL_2': 'rxn00908',
#  'GLYCLm': 'rxn00908',
#  'GLYCLTD_m': 'rxn00512',
#  'GLYCLTDx': 'rxn00512',
#  'GLYCLTDy': 'rxn00324',
#  'GLYCLTDym': 'rxn00324',
#  'GLYCLTt2r': 'rxn05470',
#  'GLYCLTt2rpp': 'rxn05470',
#  'HPYRRy': 'rxn01013',
#  'GLYCTO1': 'rxn00333',
#  'GLYCTO1p': 'rxn00333',
#  'GOX_m': 'rxn00333',
#  'GLYCTO2': 'rxn08655',
#  'GLYCTO3': 'rxn08656',
#  'GLYCTO4': 'rxn08657',
#  'EX_glyc_e': 'rxn05581',
#  'GLYCt': 'rxn05581',
#  'GLYCtc': 'rxn05581',
#  'GLYCtex': 'rxn05581',
#  'GLYCtg': 'rxn05581',
#  'GLYCtm': 'rxn05581',
#  'GLYCtpp': 'rxn05581',
#  'GLYCt2': 'rxn12529',
#  'GLYCth': 'rxn12529',
#  'GLYK': 'rxn00615',
#  'GLYK1': 'rxn00615',
#  'GLYKg': 'rxn00615',
#  'GLYKm': 'rxn00615',
#  'GLYLEUHYDROc': 'rxn12845',
#  'GLYNA1th': 'rxn08661',
#  'GLYNA1tm': 'rxn08661',
#  'GLYt4': 'rxn08661',
#  'GLYt4pp': 'rxn08661',
#  'GLYO1': 'rxn00269',
#  'GLYOp': 'rxn00269',
#  'GLYOX': 'rxn01274',
#  'GLYOXc': 'rxn01274',
#  'GLYOXm': 'rxn01274',
#  'GLYOX3': 'rxn08659',
#  'GLYOX_1': 'rxn01834',
#  'LGTHL': 'rxn01834',
#  'LGTHLc': 'rxn01834',
#  'GLYPROPRO1c': 'rxn18042',
#  'GLYTA': 'rxn00275',
#  'GLYTA_1': 'rxn00275',
#  'GLYabc': 'rxn10862',
#  'GLYabcpp': 'rxn10862',
#  'GLYt2m': 'rxn05582',
#  'GLYt2pp': 'rxn05582',
#  'GLYt2r': 'rxn05582',
#  'GLYt2rL': 'rxn05582',
#  'GLYth': 'rxn05582',
#  'GLYtx': 'rxn05582',
#  'EX_gly_e': 'rxn05218',
#  'GLYitr': 'rxn05218',
#  'GLYt': 'rxn05218',
#  'GLYtc': 'rxn05218',
#  'GLYtex': 'rxn05218',
#  'GLYtm': 'rxn05218',
#  'GLYtp': 'rxn05218',
#  'GLYtpp': 'rxn05218',
#  'SK_gly_c': 'rxn05218',
#  'GMP5N': 'rxn00913',
#  'NTD9': 'rxn00913',
#  'NTD9e': 'rxn00913',
#  'NTD9l': 'rxn00913',
#  'NTD9pp': 'rxn00913',
#  'GMPR': 'rxn00837',
#  'GMPS': 'rxn00916',
#  'GMPSm': 'rxn00916',
#  'GMPS2': 'rxn00917',
#  'GMPS_glu_m': 'rxn00917',
#  'GMPt6': 'rxn05471',
#  'EX_gmp_e': 'rxn08664',
#  'GMPter': 'rxn08664',
#  'GMPtex': 'rxn08664',
#  'GMPtg': 'rxn08664',
#  'GMPtm': 'rxn08664',
#  'GMPtn': 'rxn08664',
#  'GMPtn_1': 'rxn08664',
#  'HMR_7727': 'rxn08664',
#  'GND': 'rxn01115',
#  'GNDc': 'rxn01115',
#  'GNDer': 'rxn01115',
#  'PGDHh': 'rxn01115',
#  'GNK': 'rxn01275',
#  'GNK_1': 'rxn01275',
#  'GNKg': 'rxn01275',
#  'GNKh': 'rxn01275',
#  'GNKr': 'rxn01275',
#  'GNMT': 'rxn00270',
#  'GP4GH': 'rxn08667',
#  'GPDDA1': 'rxn00758',
#  'GPDDA1_1': 'rxn00758',
#  'GPDDA1pp': 'rxn00758',
#  'GPDDA2_1': 'rxn08669',
#  'GPDDA4': 'rxn08669',
#  'GPDDA4pp': 'rxn08669',
#  'GRDPt_c': 'rxn35575',
#  'GRDPth': 'rxn35575',
#  'GRTT2': 'rxn10538',
#  'GSNK': 'rxn00914',
#  'GSNKm': 'rxn00914',
#  'EX_gsn_e': 'rxn08672',
#  'GSNt': 'rxn08672',
#  'GSNtex': 'rxn08672',
#  'GSNtl': 'rxn08672',
#  'GSNtm': 'rxn08672',
#  'GSNt2': 'rxn05204',
#  'GSNt2m': 'rxn05204',
#  'GSNt2pp': 'rxn05204',
#  'GTHAMPOR': 'rxn03983',
#  'GTHAMPORh': 'rxn03983',
#  'GTHAMPORm': 'rxn03983',
#  'EX_gthox_e': 'rxn08674',
#  'GTHOXtex': 'rxn08674',
#  'GTHOXtg': 'rxn08674',
#  'GTHOXti': 'rxn08674',
#  'GTHOXtm': 'rxn08674',
#  'GTHOXtu': 'rxn08674',
#  'HMR_9628': 'rxn08674',
#  'GTHP_api': 'rxn00205',
#  'GTHPe': 'rxn00205',
#  'GTHPi': 'rxn00205',
#  'GTHPm': 'rxn00205',
#  'GTHPx': 'rxn00205',
#  'GTHRDabc2pp': 'rxn08675',
#  'GTHRDt': 'rxn08675',
#  'r1530': 'rxn08675',
#  'GTHRDabcpp': 'rxn08676',
#  'GTHRDabcv': 'rxn08676',
#  'GTHRDt2_1': 'rxn08676',
#  'EX_gthrd_e': 'rxn08677',
#  'GTHRDt2': 'rxn08677',
#  'GTHRDtex': 'rxn08677',
#  'GTHRDtm': 'rxn08677',
#  'GTHRDtr': 'rxn08677',
#  'GTHRDtu': 'rxn08677',
#  'Gthrdtg': 'rxn08677',
#  'GTHS': 'rxn00351',
#  'GTHS_1': 'rxn00351',
#  'GTHS_h': 'rxn00351',
#  'GTPCIII': 'rxn10539',
#  'GTPDPK': 'rxn00303',
#  'GTPDPK_1': 'rxn00303',
#  'GTPH1': 'rxn10791',
#  'GTPHs': 'rxn08679',
#  'GTPOPm': 'rxn00304',
#  'PYK3': 'rxn00304',
#  'GTPt2m': 'rxn13307',
#  'EX_gtp_e': 'rxn08680',
#  'GTPt_h': 'rxn08680',
#  'GTPtex': 'rxn08680',
#  'GTPtn': 'rxn08680',
#  'GUDBUTNAH': 'rxn01462',
#  'GUI1': 'rxn01080',
#  'GULN3D': 'rxn01913',
#  'GULND': 'rxn01079',
#  'GULNDer': 'rxn01079',
#  'H2ASE_syn': 'rxn07200',
#  'H2CO3D': 'rxn00102',
#  'H2CO3Dm': 'rxn00102',
#  'HCO3E': 'rxn00102',
#  'HCO3E_1_cx': 'rxn00102',
#  'HCO3Ee': 'rxn00102',
#  'HCO3Ehi': 'rxn00102',
#  'HCO3Em': 'rxn00102',
#  'HCO3En': 'rxn00102',
#  'EX_h2co3_e': 'rxn10826',
#  'EX_hco3_e': 'rxn10826',
#  'H2CO3TP': 'rxn10826',
#  'HCO3t': 'rxn10826',
#  'HCO3t2cax': 'rxn10826',
#  'HCO3tc': 'rxn10826',
#  'HCO3tcx': 'rxn10826',
#  'HCO3tex': 'rxn10826',
#  'HCO3tn': 'rxn10826',
#  'r0941': 'rxn10826',
#  'H2CO3_NAt_syn': 'rxn12800',
#  'HCO3_NAt': 'rxn12800',
#  'NAHCO3t_h': 'rxn12800',
#  'NAHCO3t_m': 'rxn12800',
#  'H2O2syn': 'rxn04958',
#  'H2SO': 'rxn08688',
#  'EX_HC00250_e': 'rxn08689',
#  'EX_h2s_e': 'rxn08689',
#  'H2St1': 'rxn08689',
#  'H2St1pp': 'rxn08689',
#  'H2St_h': 'rxn08689',
#  'H2St_m': 'rxn08689',
#  'H2Stex': 'rxn08689',
#  'r0940': 'rxn08689',
#  'DM_h2_c': 'rxn08691',
#  'EX_h2_e': 'rxn08691',
#  'H2td': 'rxn08691',
#  'H2tex': 'rxn08691',
#  'H2th': 'rxn08691',
#  'H2tm': 'rxn08691',
#  'H2tpp': 'rxn08691',
#  'H4MPTGL_atp': 'rxn10543',
#  'H4MPTGL_gtp': 'rxn10544',
#  'H4MPTS10': 'rxn10545',
#  'H4MPTS11': 'rxn10546',
#  'H4MPTS12': 'rxn10547',
#  'H4MPTS13': 'rxn10548',
#  'H4MPTS15': 'rxn10550',
#  'H4MPTS16': 'rxn10551',
#  'HACD2': 'rxn03249',
#  'HACD2_1': 'rxn03249',
#  'HACD2i': 'rxn03249',
#  'HACD2m': 'rxn03249',
#  'HMR_3100': 'rxn03249',
#  'r0733': 'rxn03249',
#  'HACD4': 'rxn03244',
#  'HACD4i': 'rxn03244',
#  'HACD4m': 'rxn03244',
#  'HACD4p': 'rxn03244',
#  'HACD5': 'rxn03242',
#  'HACD5i': 'rxn03242',
#  'HACD5m': 'rxn03242',
#  'HACD5p': 'rxn03242',
#  'HACD6': 'rxn06777',
#  'HACD6i': 'rxn06777',
#  'HACD6m': 'rxn06777',
#  'HACD6p': 'rxn06777',
#  'HACD7': 'rxn03239',
#  'HACD7i': 'rxn03239',
#  'HACD7m': 'rxn03239',
#  'HACD7p': 'rxn03239',
#  'r0714': 'rxn03239',
#  'r0714_1': 'rxn03239',
#  'r0715': 'rxn03239',
#  'HACD8': 'rxn08700',
#  'HACD8i': 'rxn08700',
#  'HACD8p': 'rxn08700',
#  'HADH180_m': 'rxn08700',
#  'HACD9': 'rxn02933',
#  'HACD9m': 'rxn02933',
#  'HACNHm': 'rxn03034',
#  'HADPCOADH': 'rxn12773',
#  'HADPCOADH3': 'rxn04750',
#  'HASD': 'rxn10553',
#  'HATGH': 'rxn10554',
#  'HATIH': 'rxn10555',
#  'HATSH': 'rxn10556',
#  'HBZOPT': 'rxn03893',
#  'HBZOPTm': 'rxn03893',
#  'HBZOPT10m': 'rxn21734',
#  'HCINNMt2r': 'rxn08701',
#  'HCINNMt2rpp': 'rxn08701',
#  'EX_3hcinnm_e': 'rxn08702',
#  'HCINNMtex': 'rxn08702',
#  'AACT': 'rxn00202',
#  'HCITS': 'rxn00202',
#  'HCITSm': 'rxn00202',
#  'HCITSn': 'rxn00202',
#  'HCO3_h_thi': 'rxn34228',
#  'HCO3_h_ti': 'rxn34228',
#  'HCO3_h_tmi': 'rxn34228',
#  'HCYSMT': 'rxn00452',
#  'HCYSt2p': 'rxn09837',
#  'DM_hcys__L_c': 'rxn33393',
#  'EX_hcys__L_e': 'rxn33393',
#  'HCYSte': 'rxn33393',
#  'HCYStex': 'rxn33393',
#  'HCYSth': 'rxn33393',
#  'HCYStm': 'rxn33393',
#  'HDC': 'rxn00866',
#  'HISDC': 'rxn00866',
#  'HDCACBP': 'rxn31577',
#  'HDCAt2': 'rxn10162',
#  'HDCAt2pp': 'rxn10162',
#  'HDD2COAtx': 'rxn31916',
#  'HDDACBP': 'rxn31576',
#  'HDECAACBP': 'rxn31573',
#  'HDH': 'rxn00859',
#  'HDHh': 'rxn00859',
#  'HISTD': 'rxn00859',
#  'HEPT1': 'rxn08710',
#  'HEPT2': 'rxn08711',
#  'HEPT3': 'rxn08712',
#  'HETZK': 'rxn03075',
#  'HETZK_1': 'rxn03075',
#  'HEXDPtm': 'rxn13313',
#  'HEXSabc': 'rxn05585',
#  'HEXt2rpp': 'rxn08714',
#  'HG2abcpp': 'rxn08715',
#  'HG2t3pp': 'rxn08716',
#  'EX_hg2_e': 'rxn05586',
#  'HG2tex': 'rxn05586',
#  'HG2tppi': 'rxn05586',
#  'HGt': 'rxn05586',
#  'EX_hgentis_e': 'rxn31930',
#  'HGENTISt': 'rxn31930',
#  'HGENTIStex': 'rxn31930',
#  'HGENTISth': 'rxn31930',
#  'HGNTOR': 'rxn01825',
#  'HICITDm': 'rxn03324',
#  'HISDr': 'rxn00867',
#  'HISTP': 'rxn02160',
#  'HISTP_1': 'rxn02160',
#  'HP': 'rxn02160',
#  'HPh': 'rxn02160',
#  'HISabc': 'rxn05164',
#  'HISabcpp': 'rxn05164',
#  'HISt2r1': 'rxn13314',
#  'HISt6': 'rxn13314',
#  'r2416': 'rxn13314',
#  'EX_his__L_e': 'rxn08721',
#  'HIStex': 'rxn08721',
#  'HIStiDF': 'rxn08721',
#  'SK_his__L_c': 'rxn08721',
#  'r1067': 'rxn08721',
#  'HIUH': 'rxn04453',
#  'HIUH_c': 'rxn04453',
#  'HURH': 'rxn04453',
#  'HKYNH': 'rxn01930',
#  'HKt': 'rxn08762',
#  'HKtpp': 'rxn08762',
#  'Kabc': 'rxn08762',
#  'Kabcpp': 'rxn08762',
#  'HMBS': 'rxn00060',
#  'PPBNGD': 'rxn00060',
#  'HMGCOAtm': 'rxn09743',
#  'HMGCOAtx': 'rxn09743',
#  'HMPK1': 'rxn02484',
#  'HMPK1_1': 'rxn02484',
#  'HMPK_h': 'rxn02484',
#  'HMSD2': 'rxn03654',
#  'HOMt2pp': 'rxn08722',
#  'EX_hom__L_e': 'rxn08723',
#  'HOMtex': 'rxn08723',
#  'r2535': 'rxn08723',
#  'r2535m': 'rxn08723',
#  'HOPNTAL': 'rxn00540',
#  'HOXPRm': 'rxn01280',
#  'HOXPRx': 'rxn01280',
#  'TRSARr': 'rxn01280',
#  'HPCLx': 'rxn41783',
#  'HPCLx_1': 'rxn41783',
#  'HPHL': 'rxn02181',
#  'PRPNCOAHYDm': 'rxn02181',
#  'PRPNCOAHYDx': 'rxn02181',
#  'HPI': 'rxn01015',
#  'HPYRI': 'rxn01015',
#  'HPPPNt2r': 'rxn08725',
#  'HPPPNt2rpp': 'rxn08725',
#  'EX_3hpppn_e': 'rxn08726',
#  'HPPPNtex': 'rxn08726',
#  'HPROa': 'rxn02356',
#  'HPROx': 'rxn02356',
#  'HPROxm': 'rxn02356',
#  'PY5CCR': 'rxn02356',
#  'HPROb': 'rxn02358',
#  'HPROym': 'rxn02358',
#  'PY5CCR2': 'rxn02358',
#  'HPYRDC': 'rxn01014',
#  'HPYRDCm': 'rxn01014',
#  'HMR_8776': 'rxn33611',
#  'HPYRtp': 'rxn33611',
#  'HQNt6': 'rxn05678',
#  'HSD3B12r': 'rxn01337',
#  'HSD3B13': 'rxn02385',
#  'HSD3B13r': 'rxn02385',
#  'HSDA': 'rxn19903',
#  'HSDH': 'rxn01302',
#  'HSDy': 'rxn01302',
#  'HSDH_h': 'rxn01301',
#  'HSDH_m': 'rxn01301',
#  'HSDxi': 'rxn01301',
#  'HSK': 'rxn01300',
#  'HSK_1': 'rxn01300',
#  'HSK_2': 'rxn01300',
#  'HSPMS': 'rxn00015',
#  'HSST': 'rxn01304',
#  'HTDCACBP': 'rxn31575',
#  'EX_caproic_e': 'rxn08732',
#  'EX_hxa_e': 'rxn08732',
#  'HMR_0167': 'rxn08732',
#  'HXAt1': 'rxn08732',
#  'HXAt2': 'rxn08732',
#  'HXAt3': 'rxn08732',
#  'HXAtex': 'rxn08732',
#  'HXCT': 'rxn08733',
#  'HYD1': 'rxn08734',
#  'HYD1pp': 'rxn08734',
#  'HYD2': 'rxn08735',
#  'HYD2pp': 'rxn08735',
#  'HYD3': 'rxn08736',
#  'HYD3pp': 'rxn08736',
#  'HYDA': 'rxn05759',
#  'HYDAh': 'rxn05759',
#  'HYDAm': 'rxn05759',
#  'HYNE': 'rxn00201',
#  'HYPOE': 'rxn01808',
#  'EX_iamac_e': 'rxn13315',
#  'IAMACt': 'rxn13315',
#  'EX_iamoh_e': 'rxn13316',
#  'IAMOHt': 'rxn13316',
#  'IAMOHtm': 'rxn13316',
#  'EX_ibutac_e': 'rxn13318',
#  'IBUTACt': 'rxn13318',
#  'EX_ibutoh_e': 'rxn13319',
#  'IBUTOHt': 'rxn13319',
#  'IBUTOHtm': 'rxn13319',
#  'ICDHhr': 'rxn00198',
#  'ICDHym': 'rxn00198',
#  'ICDHyp': 'rxn00198',
#  'ICDHyr': 'rxn00198',
#  'ICDHx': 'rxn00505',
#  'ICDHxm': 'rxn00505',
#  'IMPC': 'rxn00832',
#  'ICHORS': 'rxn01258',
#  'ICHORS_h': 'rxn01258',
#  'ICITt10': 'rxn05589',
#  'ICITt2': 'rxn05590',
#  'ICITt_kt': 'rxn05590',
#  'DM_icit_h': 'rxn12803',
#  'EX_icit_e': 'rxn12803',
#  'ICITt_x': 'rxn12803',
#  'ICITtex': 'rxn12803',
#  'ICITtr': 'rxn12803',
#  'ICITtupp': 'rxn12803',
#  'ICL': 'rxn00336',
#  'ICL_1': 'rxn00336',
#  'ICL_x': 'rxn00336',
#  'EX_id3acald_e': 'rxn09742',
#  'ID3ACALDt': 'rxn09742',
#  'ID3ACALDtm': 'rxn09742',
#  'IDHPOXOX4': 'rxn02295',
#  'IDIh': 'rxn00830',
#  'IPDDI': 'rxn00830',
#  'IPDDIx': 'rxn00830',
#  'IDOND': 'rxn03953',
#  'IDOND2': 'rxn03954',
#  'IDONt2r': 'rxn08742',
#  'IDONt2rpp': 'rxn08742',
#  'EX_idon__L_e': 'rxn08743',
#  'IDONtex': 'rxn08743',
#  'IDS1': 'rxn04113',
#  'IPDPS_syn': 'rxn04113',
#  'IG3PS': 'rxn03135',
#  'IG3PS_1': 'rxn03135',
#  'IMGPSh': 'rxn03135',
#  'IGPDH': 'rxn02473',
#  'IGPDH_1': 'rxn02473',
#  'IGPDh': 'rxn02473',
#  'ILEDHr': 'rxn09896',
#  'ILEOX': 'rxn01574',
#  'ILEabc': 'rxn05179',
#  'ILEabcpp': 'rxn05179',
#  'ILEt2r': 'rxn05244',
#  'ILEt2rpp': 'rxn05244',
#  'ILEt7': 'rxn05244',
#  'ILEth': 'rxn05244',
#  'ILEtm': 'rxn05244',
#  'ILEt4': 'rxn05241',
#  'ILEt_h': 'rxn05241',
#  'ILEt_m': 'rxn05241',
#  'EX_ile__L_e': 'rxn08747',
#  'ILEtec': 'rxn08747',
#  'ILEtex': 'rxn08747',
#  'ILEtmi': 'rxn08747',
#  'SK_ile__L_c': 'rxn08747',
#  'ILEt3pp': 'rxn13321',
#  'ILEt6': 'rxn13321',
#  'IMPHL_1_h': 'rxn02789',
#  'IPPMIb': 'rxn02789',
#  'IMPHL_2_h': 'rxn02811',
#  'IPPMIa': 'rxn02811',
#  'IMPD': 'rxn00834',
#  'IMPDg': 'rxn00834',
#  'IMPDm': 'rxn00834',
#  'EX_imp_e': 'rxn08749',
#  'IMPtex': 'rxn08749',
#  'IMPth': 'rxn08749',
#  'IMPtr': 'rxn08749',
#  'IND3ACt2r': 'rxn10560',
#  'EX_ind3ac_e': 'rxn09741',
#  'IND3ACt': 'rxn09741',
#  'IND3ACtex': 'rxn09741',
#  'IND3ACtm': 'rxn09741',
#  'SK_ind3ac_c': 'rxn09741',
#  'EX_ind3eth_e': 'rxn13324',
#  'IND3ETHt': 'rxn13324',
#  'IND3ETHtm': 'rxn13324',
#  'INDPYRD': 'rxn01450',
#  'INOSR': 'rxn30488',
#  'INOSTO': 'rxn00880',
#  'INOSTt4pp': 'rxn08752',
#  'INSTt4': 'rxn08752',
#  'INOSTtpp': 'rxn05593',
#  'INSTt2': 'rxn05593',
#  'INSCR': 'rxn05743',
#  'INSK': 'rxn00835',
#  'INSKm': 'rxn00835',
#  'EX_inost_e': 'rxn08755',
#  'INOST_Et': 'rxn08755',
#  'INSTtex': 'rxn08755',
#  'MYOIt_h': 'rxn08755',
#  'MYOIt_m': 'rxn08755',
#  'r0826': 'rxn08755',
#  'EX_ins_e': 'rxn08754',
#  'INSt': 'rxn08754',
#  'INStex': 'rxn08754',
#  'INStl': 'rxn08754',
#  'INStm': 'rxn08754',
#  'INSt2': 'rxn05316',
#  'INSt2pp': 'rxn05316',
#  'IPDPS': 'rxn08756',
#  'IPDPth': 'rxn13332',
#  'IPDPtm': 'rxn13332',
#  'IPDPtr': 'rxn13332',
#  'IPDPtx': 'rxn13332',
#  'IPKK': 'rxn03519',
#  'MI13456PK': 'rxn03519',
#  'MI13456PKn': 'rxn03519',
#  'IMPDH_h': 'rxn03062',
#  'IPMD': 'rxn03062',
#  'IPPS': 'rxn00902',
#  'IPPSh': 'rxn00902',
#  'IPPSm': 'rxn00902',
#  'ISETACabcpp': 'rxn05594',
#  'ISTNTabc': 'rxn05594',
#  'EX_isetac_e': 'rxn08759',
#  'EX_istnt_e': 'rxn08759',
#  'ISETACtex': 'rxn08759',
#  'ITCOAL1m': 'rxn01732',
#  'ITCOALm': 'rxn01731',
#  'ITK1K': 'rxn02490',
#  'MI3456PK': 'rxn02490',
#  'ITKK': 'rxn02489',
#  'MI1346PKn': 'rxn02489',
#  'ITKPHn': 'rxn02458',
#  'MI1345PP': 'rxn02458',
#  'ITKPK': 'rxn02456',
#  'K2L4Aabcpp': 'rxn08760',
#  'EX_kdo2lipid4_e': 'rxn08761',
#  'K2L4Atex': 'rxn08761',
#  'KARI_23dhmb': 'rxn03068',
#  'KARI_23dhmp': 'rxn03435',
#  'KARI_23dhmp_1': 'rxn03435',
#  'KARI_3hmoa': 'rxn02187',
#  'KAS10': 'rxn10026',
#  'KAS13': 'rxn10029',
#  'KAS19SA': 'rxn10863',
#  'KAS2': 'rxn05744',
#  'KAS20SA': 'rxn10864',
#  'KAS5': 'rxn10034',
#  'KAS9': 'rxn10038',
#  'KG6PDC': 'rxn04928',
#  'Kt3g': 'rxn05596',
#  'Kt3pp': 'rxn05596',
#  'Kt3r': 'rxn05596',
#  'KYN': 'rxn00728',
#  'KYN3OX': 'rxn01438',
#  'KYNAKGAT': 'rxn01435',
#  'KYNAKGATm': 'rxn01435',
#  'KYNATESYN': 'rxn02467',
#  'KYNATESYNm': 'rxn02467',
#  'DM_k_c': 'rxn05206',
#  'DM_k_g': 'rxn05206',
#  'EX_k_e': 'rxn05206',
#  'Kt1': 'rxn05206',
#  'Ktex': 'rxn05206',
#  'Ktu': 'rxn05206',
#  'Kt2pp': 'rxn05595',
#  'Kt2r': 'rxn05595',
#  'LAAL1': 'rxn09897',
#  'LAAL13': 'rxn09901',
#  'LAAL19': 'rxn09907',
#  'LAAL2': 'rxn09908',
#  'LAAL20': 'rxn09909',
#  'LAAL30': 'rxn09920',
#  'LAAL35': 'rxn09925',
#  'LAAL36': 'rxn09926',
#  'EX_lac__L_e': 'rxn08795',
#  'LACLt': 'rxn08795',
#  'LACLt2': 'rxn08795',
#  'L_LACtcm': 'rxn08795',
#  'L_LACtex': 'rxn08795',
#  'LADGMDH': 'rxn08773',
#  'EX_LalaLglu_e': 'rxn30261',
#  'LALALGLUtex': 'rxn30261',
#  'LALDD': 'rxn15660',
#  'LALDO2': 'rxn15660',
#  'ALCD22_D': 'rxn01831',
#  'LALDO2x': 'rxn01831',
#  'LALDO': 'rxn02211',
#  'LALGP': 'rxn08775',
#  'EX_lanost_e': 'rxn12860',
#  'LANOSTt': 'rxn12860',
#  'LANOSTtr': 'rxn12860',
#  'r0988': 'rxn12860',
#  'LCADi': 'rxn01053',
#  'LCADm': 'rxn01053',
#  'LCADi_D': 'rxn01273',
#  'LCADi_Dm': 'rxn01273',
#  'LCTSabc': 'rxn05598',
#  'LCTSt': 'rxn08781',
#  'LCTStpp': 'rxn08781',
#  'LCTSt3ipp': 'rxn08779',
#  'EX_lcts_e': 'rxn08780',
#  'LCTStex': 'rxn08780',
#  'LCTStg': 'rxn08780',
#  'LCTStl': 'rxn08780',
#  'LCYSTCBOXL': 'rxn01231',
#  'SALADC2': 'rxn01231',
#  'LCYSTabc': 'rxn05599',
#  'LCYSTabcpp': 'rxn05599',
#  'LCYSTintv': 'rxn43401',
#  'EX_Lcyst_e': 'rxn33226',
#  'LCYSTtex': 'rxn33226',
#  'LDH_D': 'rxn00500',
#  'LDHm': 'rxn00500',
#  'LDH_D2': 'rxn08783',
#  'LDH_L': 'rxn00499',
#  'LDH_Lm': 'rxn00499',
#  'LLDHh': 'rxn00499',
#  'r0173': 'rxn00499',
#  'LEUabc': 'rxn05161',
#  'LEUabcpp': 'rxn05161',
#  'LEUt2r': 'rxn05243',
#  'LEUt2rpp': 'rxn05243',
#  'LEUt7': 'rxn05243',
#  'LEUth': 'rxn05243',
#  'LEUtm': 'rxn05243',
#  'LEUt4': 'rxn05240',
#  'LEUt4rpp': 'rxn05240',
#  'LEUt_h': 'rxn05240',
#  'LEUt_m': 'rxn05240',
#  'EX_leu__L_e': 'rxn08786',
#  'LEUt5m': 'rxn08786',
#  'LEUtec': 'rxn08786',
#  'LEUtex': 'rxn08786',
#  'SK_leu__L_c': 'rxn08786',
#  'LEUt3pp': 'rxn13339',
#  'LEUt6': 'rxn13339',
#  'LGNCCOAtcx': 'rxn18901',
#  'LGNCCOAtcx_1': 'rxn18901',
#  'LGNCCOAtx': 'rxn13409',
#  'TTCCOAtx': 'rxn13409',
#  'EX_lgnc_e': 'rxn09842',
#  'LGNCt': 'rxn09842',
#  'LIDOAMH': 'rxn11828',
#  'LIDODM': 'rxn34683',
#  'LIDOMO': 'rxn11822',
#  'EX_lido_e': 'rxn34425',
#  'LIDOt': 'rxn34425',
#  'LIPAabcpp': 'rxn08787',
#  'EX_lipa_e': 'rxn08791',
#  'LIPAtex': 'rxn08791',
#  'LLEUDr': 'rxn00804',
#  'EX_lnlc_e': 'rxn33504',
#  'EX_ocdcya_e': 'rxn33504',
#  'LNLCt': 'rxn33504',
#  'LNLCtexi': 'rxn33504',
#  'LNLCth': 'rxn33504',
#  'OCDCYAt': 'rxn33504',
#  'SK_lnlc_c': 'rxn33504',
#  'r0986': 'rxn33504',
#  'r0987': 'rxn33504',
#  'EX_lnlnca_e': 'rxn39015',
#  'LNLNCAt': 'rxn39015',
#  'r1364': 'rxn39015',
#  'r1365': 'rxn39015',
#  'LPLIPAL1A120pp': 'rxn08796',
#  'LPLIPAL1A180pp': 'rxn08801',
#  'LPLIPAL2A120': 'rxn08817',
#  'LPLIPAL2A140': 'rxn08818',
#  'LPLIPAL2A160': 'rxn08820',
#  'LPLIPAL2A180': 'rxn08822',
#  'LSERDHr': 'rxn04137',
#  'HMR_1516': 'rxn37501',
#  'LSTO1r': 'rxn37501',
#  'LSTO2r': 'rxn04993',
#  'LTHSTRLOR': 'rxn04993',
#  'LTHRK': 'rxn04386',
#  'LYSAM': 'rxn00321',
#  'LYSDC': 'rxn00322',
#  'LYSMO': 'rxn00312',
#  'LYSOXp': 'rxn00310',
#  'LYSOXp_1': 'rxn00310',
#  'LYSRC': 'rxn00320',
#  'LYSabc': 'rxn05151',
#  'LYSabcpp': 'rxn05151',
#  'LYSt2m': 'rxn08854',
#  'LYSt2pp': 'rxn08854',
#  'LYSt2r': 'rxn08854',
#  'LYSt_h': 'rxn08854',
#  'LYSt3pp': 'rxn05305',
#  'LYSt3r': 'rxn05305',
#  'LYSt6': 'rxn05305',
#  'LYStm': 'rxn05305',
#  'EX_lys__L_e': 'rxn08856',
#  'LYSt5r': 'rxn08856',
#  'LYStex': 'rxn08856',
#  'LYStip': 'rxn08856',
#  'LYStn': 'rxn08856',
#  'SK_lys__L_c': 'rxn08856',
#  'LYXt2pp': 'rxn05692',
#  'EX_lyx__L_e': 'rxn08859',
#  'LYX_L_Et': 'rxn08859',
#  'LYXtex': 'rxn08859',
#  'L_LACD2': 'rxn08792',
#  'L_LACD3': 'rxn08793',
#  'L_LACt2r': 'rxn05602',
#  'L_LACt2rpp': 'rxn05602',
#  'L_LACtm': 'rxn05602',
#  'r2516': 'rxn05602',
#  'L_LACt3': 'rxn10818',
#  'LacR': 'rxn01057',
#  'MAAIn': 'rxn02276',
#  'MACACI': 'rxn02276',
#  'MACOXO': 'rxn03400',
#  'MAGAH160': 'rxn34964',
#  'MAGAH180': 'rxn34965',
#  'MAGAH1819Z': 'rxn34967',
#  'MALDDH': 'rxn00160',
#  'MALDt2_2pp': 'rxn08863',
#  'EX_mal__D_e': 'rxn08864',
#  'MALDtex': 'rxn08864',
#  'MAL_D_Et': 'rxn08864',
#  'MALEI': 'rxn00803',
#  'MALGLUth': 'rxn29243',
#  'MALICITtm': 'rxn34509',
#  'MALOAAth': 'rxn09836',
#  'MALOAAtm': 'rxn09836',
#  'MALOAAtp': 'rxn09836',
#  'MALS': 'rxn00330',
#  'MALSh': 'rxn00330',
#  'MALSm': 'rxn00330',
#  'MALSp': 'rxn00330',
#  'MALT': 'rxn00022',
#  'MALTe': 'rxn00022',
#  'MALTly': 'rxn00022',
#  'MALTHXabc': 'rxn08869',
#  'MALTHXabcpp': 'rxn08869',
#  'EX_M02447_e': 'rxn08870',
#  'EX_malthx_e': 'rxn08870',
#  'MALTHXtexi': 'rxn08870',
#  'MALTPTabc': 'rxn08871',
#  'MALTPTabcpp': 'rxn08871',
#  'EX_maltpt_e': 'rxn08873',
#  'MALTPTtexi': 'rxn08873',
#  'MALTTRabc': 'rxn05608',
#  'MALTTRabcpp': 'rxn05608',
#  'EX_malttr_e': 'rxn08876',
#  'HMR_8590': 'rxn08876',
#  'MALTTRtexi': 'rxn08876',
#  'MALTTTRabc': 'rxn08877',
#  'MALTTTRabcpp': 'rxn08877',
#  'EX_M02451_e': 'rxn08878',
#  'EX_maltttr_e': 'rxn08878',
#  'MALTTTRt': 'rxn08878',
#  'MALTTTRtexi': 'rxn08878',
#  'MALTabc': 'rxn05170',
#  'MALTabcpp': 'rxn05170',
#  'MALTpts': 'rxn05607',
#  'MALTptspp': 'rxn05607',
#  'MALTt2': 'rxn09673',
#  'MAL_Dt2': 'rxn05603',
#  'EX_mal__L_e': 'rxn08868',
#  'MAL_Ltx': 'rxn08868',
#  'MALt': 'rxn08868',
#  'MALtex': 'rxn08868',
#  'SK_mal__L_c': 'rxn08868',
#  ...}

# %%
R_df = DataFrame(data = {'BiGG': R.keys(), 'SEED': R.values()})
R_df
# Out:
#                 BiGG      SEED
# 0           HMR_1095  rxn08730
# 1                 Ht  rxn08730
# 2               Htcx  rxn08730
# 3               Htex  rxn08730
# 4                Htg  rxn08730
# ...              ...       ...
# 7154  EX_galctn__L_e  rxn08577
# 7155      GALCTNLtex  rxn08577
# 7156  EX_galctn__D_e  rxn08579
# 7157       GALCTNtex  rxn08579
# 7158           GALFT  rxn10687
#
# [7159 rows x 2 columns]

# %%
R_df.to_csv(r'reactions.tsv', header = True, index = False, sep = "\t")
